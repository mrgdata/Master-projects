# %% [markdown]
# ## 1. Cargamos dataset

# %%
import pandas as pd

pd.options.display.max_colwidth = 10000
df = pd.read_csv("villagers.csv")
df = df.reset_index(drop=True)
df.head(5)
# Out:
#       Name                                    Icon Image  \
# 0  Admiral  https://acnhcdn.com/latest/NpcIcon/brd06.png
# 1  Agent S  https://acnhcdn.com/latest/NpcIcon/squ05.png
# 2    Agnes  https://acnhcdn.com/latest/NpcIcon/pig17.png
# 3       Al  https://acnhcdn.com/latest/NpcIcon/gor08.png
# 4  Alfonso  https://acnhcdn.com/latest/NpcIcon/crd00.png
#
#                                              Photo Image  \
# 0  https://acnhcdn.com/latest/NpcBromide/NpcNmlBrd06.png
# 1  https://acnhcdn.com/latest/NpcBromide/NpcNmlSqu05.png
# 2  https://acnhcdn.com/latest/NpcBromide/NpcNmlPig17.png
# 3  https://acnhcdn.com/latest/NpcBromide/NpcNmlGor08.png
# 4  https://acnhcdn.com/latest/NpcBromide/NpcNmlCrd00.png
#
#                                                            House Image  \
# 0     https://acnhcdn.com/drivesync/render/houses/brd06_39_Admiral.png
# 1  https://acnhcdn.com/drivesync/render/houses/squ05_357_Agent%20S.png
# 2      https://acnhcdn.com/drivesync/render/houses/pig17_313_Agnes.png
# 3         https://acnhcdn.com/drivesync/render/houses/gor08_190_Al.png
# 4    https://acnhcdn.com/drivesync/render/houses/crd00_102_Alfonso.png
#
#      Species  Gender Personality Subtype    Hobby Birthday  ...  Style 2  \
# 0       Bird    Male      Cranky       A   Nature     1/27  ...     Cool
# 1   Squirrel  Female       Peppy       B  Fitness      7/2  ...   Simple
# 2        Pig  Female  Big Sister       A     Play     4/21  ...  Elegant
# 3    Gorilla    Male        Lazy       B  Fitness    10/18  ...   Active
# 4  Alligator    Male        Lazy       B     Play      6/9  ...   Simple
#
#   Color 1 Color 2 Default Clothing               Wallpaper  \
# 0   Black    Blue           3164.0          dirt-clod wall
# 1    Blue   Black          12036.0           concrete wall
# 2    Pink   White           4290.0  gray molded-panel wall
# 3     Red   White           3244.0           concrete wall
# 4     Red    Blue           7969.0    yellow playroom wall
#
#                  Flooring  \
# 0                  tatami
# 1  colorful tile flooring
# 2      arabesque flooring
# 3   green rubber flooring
# 4    green honeycomb tile
#
#                                                     Furniture List  \
# 0        717;1849;7047;2736;787;5970;3449;3622;3802;4106;3438;4029
# 1  7845;7150;3468;4080;290;3971;3449;1708;4756;2560;4753;7323;7789
# 2  4129;7236;7235;7802;896;3428;4027;7325;3958;7136;3951;3773;7801
# 3            1452;4078;4013;833;4116;3697;7845;3307;3946;3960;7800
# 4             4763;3205;3701;1557;3623;85;3208;3584;4761;1217;3702
#
#                                                                                                                                                                                                Furniture Name List  \
# 0                                                              clay furnace;kotatsu;zen cushion;retro fan;tape deck;firewood;wooden stool;floor seat;pine bonsai tree;pendulum clock;wooden end table;rotary phone
# 1  pull-up-bar stand;blue corner;beach towel;long bathtub;treadmill;imperial partition;wooden stool;cassette player;throwback wall clock;wooden chest;throwback wrestling figure;brown wooden-deck rug;drying rack
# 2                    monstera;lily record player;rose bed;pet bed;cat tower;wall-mounted TV (50 in.);floral swag;ivory medium round mat;antique mini table;cat grass;antique console table;terrarium;pet food bowl
# 3                                                weight bench;barbell;punching bag;upright locker;whiteboard;portable radio;pull-up-bar stand;digital scale;outdoor table;handy water cooler;protein shaker bottle
# 4                                  throwback dino screen;wooden-block stereo;writing desk;wooden-block bed;toy box;train set;wooden-block wall clock;writing poster;throwback rocket;standing toilet;writing chair
#
#   Filename    Unique Entry ID
# 0    brd06  B3RyfNEqwGmcccRC3
# 1    squ05  SGMdki6dzpDZyXAw5
# 2    pig17  jzWCiDPm9MqtCfecP
# 3    gor08  LBifxETQJGEaLhBjC
# 4    crd00  REpd8KxB8p9aGBRSE
#
# [5 rows x 24 columns]

# %% [markdown]
# ## 2. Convertimos la fecha en formato date

# %%
# hacemos split

df[['Month','Day']] = df.Birthday.str.split("/",expand=True,)

#creamos año

df['Year'] = 2001

# convertimos a strings y creamos fecha

df["Cumple"] = df["Day"].astype(str) + "-" + df["Month"].astype(str) + "-" + df["Year"].astype(str) 

# drop columnas 


# cambiamos a formato fecha fecha

df["Cumple"] =  pd.to_datetime(df['Cumple'], format='%d-%m-%Y')

df.drop(["Birthday", 'Month', 'Day', 'Year'], axis=1, inplace=True)

df
# Out:
#          Name                                    Icon Image  \
# 0     Admiral  https://acnhcdn.com/latest/NpcIcon/brd06.png
# 1     Agent S  https://acnhcdn.com/latest/NpcIcon/squ05.png
# 2       Agnes  https://acnhcdn.com/latest/NpcIcon/pig17.png
# 3          Al  https://acnhcdn.com/latest/NpcIcon/gor08.png
# 4     Alfonso  https://acnhcdn.com/latest/NpcIcon/crd00.png
# ..        ...                                           ...
# 386    Winnie  https://acnhcdn.com/latest/NpcIcon/hrs05.png
# 387  Wolfgang  https://acnhcdn.com/latest/NpcIcon/wol02.png
# 388      Yuka  https://acnhcdn.com/latest/NpcIcon/kal00.png
# 389      Zell  https://acnhcdn.com/latest/NpcIcon/der02.png
# 390    Zucker  https://acnhcdn.com/latest/NpcIcon/ocp02.png
#
#                                                Photo Image  \
# 0    https://acnhcdn.com/latest/NpcBromide/NpcNmlBrd06.png
# 1    https://acnhcdn.com/latest/NpcBromide/NpcNmlSqu05.png
# 2    https://acnhcdn.com/latest/NpcBromide/NpcNmlPig17.png
# 3    https://acnhcdn.com/latest/NpcBromide/NpcNmlGor08.png
# 4    https://acnhcdn.com/latest/NpcBromide/NpcNmlCrd00.png
# ..                                                     ...
# 386  https://acnhcdn.com/latest/NpcBromide/NpcNmlHrs05.png
# 387  https://acnhcdn.com/latest/NpcBromide/NpcNmlWol02.png
# 388  https://acnhcdn.com/latest/NpcBromide/NpcNmlKal00.png
# 389  https://acnhcdn.com/latest/NpcBromide/NpcNmlDer02.png
# 390  https://acnhcdn.com/latest/NpcBromide/NpcNmlOcp02.png
#
#                                                              House Image  \
# 0       https://acnhcdn.com/drivesync/render/houses/brd06_39_Admiral.png
# 1    https://acnhcdn.com/drivesync/render/houses/squ05_357_Agent%20S.png
# 2        https://acnhcdn.com/drivesync/render/houses/pig17_313_Agnes.png
# 3           https://acnhcdn.com/drivesync/render/houses/gor08_190_Al.png
# 4      https://acnhcdn.com/drivesync/render/houses/crd00_102_Alfonso.png
# ..                                                                   ...
# 386     https://acnhcdn.com/drivesync/render/houses/hrs05_211_Winnie.png
# 387   https://acnhcdn.com/drivesync/render/houses/wol02_379_Wolfgang.png
# 388       https://acnhcdn.com/drivesync/render/houses/kal00_220_Yuka.png
# 389         https://acnhcdn.com/drivesync/render/houses/der02_0_Zell.png
# 390     https://acnhcdn.com/drivesync/render/houses/ocp02_267_Zucker.png
#
#        Species  Gender Personality Subtype      Hobby Catchphrase  ...  \
# 0         Bird    Male      Cranky       A     Nature     aye aye  ...
# 1     Squirrel  Female       Peppy       B    Fitness    sidekick  ...
# 2          Pig  Female  Big Sister       A       Play     snuffle  ...
# 3      Gorilla    Male        Lazy       B    Fitness     ayyyeee  ...
# 4    Alligator    Male        Lazy       B       Play    it'sa me  ...
# ..         ...     ...         ...     ...        ...         ...  ...
# 386      Horse  Female       Peppy       B    Fashion      hay-OK  ...
# 387       Wolf    Male      Cranky       B  Education     snarrrl  ...
# 388      Koala  Female      Snooty       B    Fashion     tsk tsk  ...
# 389       Deer    Male        Smug       A      Music       pronk  ...
# 390    Octopus    Male        Lazy       A     Nature       bloop  ...
#
#     Color 1 Color 2 Default Clothing                Wallpaper  \
# 0     Black    Blue           3164.0           dirt-clod wall
# 1      Blue   Black          12036.0            concrete wall
# 2      Pink   White           4290.0   gray molded-panel wall
# 3       Red   White           3244.0            concrete wall
# 4       Red    Blue           7969.0     yellow playroom wall
# ..      ...     ...              ...                      ...
# 386   White    Gray           7648.0      backyard-fence wall
# 387   Black   Green           4207.0  dark wooden-mosaic wall
# 388  Orange  Yellow           7676.0      beige art-deco wall
# 389  Purple    Gray           3676.0           cityscape wall
# 390    Blue  Yellow           3254.0         chain-link fence
#
#                         Flooring  \
# 0                         tatami
# 1         colorful tile flooring
# 2             arabesque flooring
# 3          green rubber flooring
# 4           green honeycomb tile
# ..                           ...
# 386                backyard lawn
# 387              stripe flooring
# 388       simple purple flooring
# 389  monochromatic tile flooring
# 390                backyard lawn
#
#                                                                                 Furniture List  \
# 0                                    717;1849;7047;2736;787;5970;3449;3622;3802;4106;3438;4029
# 1                              7845;7150;3468;4080;290;3971;3449;1708;4756;2560;4753;7323;7789
# 2                              4129;7236;7235;7802;896;3428;4027;7325;3958;7136;3951;3773;7801
# 3                                        1452;4078;4013;833;4116;3697;7845;3307;3946;3960;7800
# 4                                         4763;3205;3701;1557;3623;85;3208;3584;4761;1217;3702
# ..                                                                                         ...
# 386                                     1626;1626;5970;4003;3509;1620;1627;3467;1631;1170;1157
# 387  4117;7323;7323;3275;4109;3270;3196;4338;3200;3562;3271;3818;1043;3194;3282;3193;4114;7800
# 388                                            3957;3955;2554;3974;3951;794;4106;3959;3958;997
# 389                                       1875;863;4129;4053;4053;3951;794;3775;4046;4230;3681
# 390                 4042;4412;7526;4077;4077;3064;4077;3946;3617;3697;4019;3618;3344;3672;3672
#
#                                                                                                                                                                                                                                                                                                        Furniture Name List  \
# 0                                                                                                                                                                      clay furnace;kotatsu;zen cushion;retro fan;tape deck;firewood;wooden stool;floor seat;pine bonsai tree;pendulum clock;wooden end table;rotary phone
# 1                                                                                                          pull-up-bar stand;blue corner;beach towel;long bathtub;treadmill;imperial partition;wooden stool;cassette player;throwback wall clock;wooden chest;throwback wrestling figure;brown wooden-deck rug;drying rack
# 2                                                                                                                            monstera;lily record player;rose bed;pet bed;cat tower;wall-mounted TV (50 in.);floral swag;ivory medium round mat;antique mini table;cat grass;antique console table;terrarium;pet food bowl
# 3                                                                                                                                                        weight bench;barbell;punching bag;upright locker;whiteboard;portable radio;pull-up-bar stand;digital scale;outdoor table;handy water cooler;protein shaker bottle
# 4                                                                                                                                          throwback dino screen;wooden-block stereo;writing desk;wooden-block bed;toy box;train set;wooden-block wall clock;writing poster;throwback rocket;standing toilet;writing chair
# ..                                                                                                                                                                                                                                                                                                                     ...
# 386                                                                                                                                                                  iron garden chair;iron garden chair;firewood;cute music player;garden bench;hammock;iron garden table;tea set;garden faucet;swinging bench;brick oven
# 387  wood-burning stove;brown wooden-deck rug;brown wooden-deck rug;ironwood clock;double-door refrigerator;ironwood kitchenette;ironwood dresser;portable record player;ironwood bed;iron wall rack;ironwood cupboard;pennant;microwave;ironwood low table;pop-up toaster;ironwood chair;tissue box;protein shaker bottle
# 388                                                                                                                                                           antique bed;antique vanity;double sofa;imperial low table;antique console table;phonograph;pendulum clock;antique wardrobe;antique mini table;incense burner
# 389                                                                                                                                           grand piano;billiard table;monstera;rattan armchair;rattan armchair;antique console table;phonograph;hanging terrarium;rattan end table;glass holder with candle;piano bench
# 390                                                                                                        log bench;cotton-candy stall;outdoor generator;party garland;party garland;cooler box;party garland;outdoor table;stall;portable radio;stand mixer;cutting board;steamer-basket set;cardboard box;cardboard box
#
#     Filename    Unique Entry ID     Cumple
# 0      brd06  B3RyfNEqwGmcccRC3 2001-01-27
# 1      squ05  SGMdki6dzpDZyXAw5 2001-07-02
# 2      pig17  jzWCiDPm9MqtCfecP 2001-04-21
# 3      gor08  LBifxETQJGEaLhBjC 2001-10-18
# 4      crd00  REpd8KxB8p9aGBRSE 2001-06-09
# ..       ...                ...        ...
# 386    hrs05  b4HwfyvThyipScSAv 2001-01-31
# 387    wol02  RbF2wcn6jRxtgLDRd 2001-11-25
# 388    kal00  QDcxk3dCNT6yeD9hk 2001-07-20
# 389    der02  LodBWtdMRZbjFNga9 2001-06-07
# 390    ocp02  2F5tipHqgmWvWXTLC 2001-03-08
#
# [391 rows x 24 columns]

# %% [markdown]
# ## 3. Cargamos los módulos necesarios

# %%
import requests
from IPython.display import display
from PIL import Image

# %% [markdown]
# ## 4. ¡A ver qué personaje sale!

# %%
year = "2001"
print("¿En qué mes cumples años? Por favor, inserta el número")
mes = str(input())
print("¿En qué día cumples años?")
day = str(input())
date = day  + "-"+ mes +"-"+ year
try: 
    date =  pd.to_datetime(date, format='%d-%m-%Y')
except ValueError:
    print("te has confundido")
date
pd.options.display.max_colwidth = 10000
a = df.loc[(df["Cumple"] == date)]
img_url = list(a["Photo Image"])
name = list(a["Name"])
house_url = list(a["House Image"])
persona = list(a["Personality"])
frase = list(a["Catchphrase"])
cancion = list(a["Favorite Song"])
for i, j, l, m, q, k in zip(img_url, name, persona, frase, cancion, house_url):    # lista comprensiva
    img = Image.open(requests.get(i, stream = True).raw)
    print("Compartes cumple con {}".format(j))
    display(img)
    print("Su personalidad es: {}".format(l))
    print("Siempre dice {}".format(m))
    print("Su canción favorita es {}".format(q))
    img0 = Image.open(requests.get(k, stream = True).raw)
    print("Y vive en esta casa")
    display(img0)
# Out:
# ¿En qué mes cumples años? Por favor, inserta el número
# 11
# ¿En qué día cumples años?
# 22
# Compartes cumple con Claudia
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=256x256 at 0x1F54AF9FD30>
# Su personalidad es: Snooty
# Siempre dice ooh la la
# Su canción favorita es K.K. Synth
# Y vive en esta casa
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1024x1024 at 0x1F54B0F4430>
